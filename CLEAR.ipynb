# %% [markdown]
# <a href="https://colab.research.google.com/github/dongmeisun/dongmeisun/blob/main/CLEAR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cd40c435-55a2-4427-99fd-50811928002e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cd40c435-55a2-4427-99fd-50811928002e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
df = pd.read_csv(io.BytesIO(uploaded[ 'antibody (1).csv' ]))
df.head()
#df = pd.DataFrame(data)
# Out:
#      pid  AgeRA  AgeScreen  DisDurMonths    IFNGR1    IFNGR2  Fibrinogen_19  \
# 0  X1001   54.6       57.0            29  0.042588  0.931017       6.000000
# 1  X1004   49.8       57.1            87  0.034166  0.281233       8.138485
# 2  X1005   18.3       55.6           447  0.070039  0.715094       8.000000
# 3  X1006   45.0       55.3           124  0.023560  0.413735       4.634579
# 4  X1007   28.0       42.3           171  0.025762  0.562074       3.716443
#
#        H2B_A    H2B_Cit    H2A_Cit  ...  Clusterin_231  Fibrinogen_A  \
# 0   8.000000  19.000000  15.000000  ...      15.000000      9.000000
# 1   5.751148   9.176310   9.045798  ...       7.142164      6.795958
# 2  13.500000  25.000000  26.000000  ...      30.000000     18.000000
# 3   3.680795   4.203631   4.437902  ...       5.519146      3.759936
# 4   4.108267   5.319154   4.355830  ...       4.643462      3.883239
#
#     FibA_582   FibB_246     FibA_616       CCP__8      Fil_48   ApoE_Cit  \
# ...

# %%
df=df.drop(["pid"], axis = 1)
df.shape
# Out:
# (577, 24)

# %%
df.describe().T
# Out:
#                count        mean         std        min        25%  \
# AgeRA          577.0   45.098787   12.451320  17.300000  37.000000
# AgeScreen      577.0   55.818544   11.177858  24.800000  49.100000
# DisDurMonths   577.0  128.636049  109.299963   1.000000  38.000000
# IFNGR1         577.0    0.023059    0.017348   0.001394   0.012880
# IFNGR2         577.0    0.456420    0.251490   0.070699   0.280713
# Fibrinogen_19  577.0    4.735928   17.084473   1.468936   2.527243
# H2B_A          577.0    6.904790   48.034907   2.354348   3.198921
# H2B_Cit        577.0    7.559194   33.287695   2.039149   3.326971
# H2A_Cit        577.0    8.492588   43.437722   2.205167   3.405374
# Biglycan_247   577.0    9.468359   57.138221   2.390973   3.360677
# H2A_a          577.0    9.689920   69.908651   2.276847   3.133411
# Enolase_1A     577.0    8.500191   62.044324   2.381762   3.059825
# Vim_58         577.0   16.666073  185.396132   2.397765   3.252967
# ...

# %%
for col in con_col.columns[1:]:
    print(col)

    print('Skew :', round(con_col[col].skew(), 2))

    plt.figure(figsize = (15, 4))

    plt.subplot(1, 2, 1)

    con_col[col].hist(bins = 10, grid = False)

    plt.ylabel('count')

    plt.subplot(1, 2, 2)

    sns.boxplot(x = con_col[col])

    plt.show()
# Out:
# AgeScreen
# Skew : 0.09
# DisDurMonths
# Skew : 1.22
# IFNGR1
# Skew : 2.76
# IFNGR2
# Skew : 1.52
# CRP
# Skew : 4.34
# HAQScore
# Skew : -0.05
# TenderBL
# Skew : 1.28
# SwollenBL
# Skew : 1.52
# JAMBL
# Skew : 2.51
# ErosionTot0
# Skew : 3.76
# NarrowTot0
# Skew : 2.12
# OverllTot0
# Skew : 2.59
# Fibrinogen_19
# Skew : 21.94
# H2B_A
# Skew : 21.58
# H2B_Cit
# Skew : 16.36
# H2A_Cit
# Skew : 14.82
# Biglycan_247
# Skew : 14.78
# H2A_a
# Skew : 18.79
# Enolase_1A
# Skew : 17.24
# Vim_58
# Skew : 19.7
# FibA_556
# Skew : 12.43
# Clusterin_231
# Skew : 15.05
# Fibrinogen_A
# Skew : 15.15
# FibA_582
# Skew : 13.6
# FibB_246
# Skew : 14.16
# FibA_616
# Skew : 13.94
# CCP__8
# Skew : 10.62
# Fil_48
# Skew : 13.83
# ApoE_Cit
# Skew : 10.06
# Vimentin_Cit
# Skew : 19.04
# ApoE_277
# Skew : 21.21

# %%
plt.figure(figsize  = (10, 10))

sns.heatmap(df.corr(), annot = True, cmap = "YlGnBu")

plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-eb3c0f26-e103-43b0-8d18-756d13f85589" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eb3c0f26-e103-43b0-8d18-756d13f85589">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
df1 = pd.read_csv(io.BytesIO(uploaded[ 'pad (1).csv' ]))
df1.head()
#df = pd.DataFrame(data)
# Out:
#      pid  AgeRA  AgeScreen  DisDurMonths    IFNGR1    IFNGR2  ErosionTot0  \
# 0  X1008   60.7       71.9           135  0.035213  0.370441           56
# 1  X1009   42.0       50.2            98  0.038560  1.388370           92
# 2  X1056   26.6       45.3           224  0.017653  0.288512           41
# 3  X1060   40.0       57.8           213  0.033825  0.548946           28
# 4  X1064   37.5       47.3           117  0.024877  0.494321            1
#
#    NarrowTot0  OverllTot0  PAD4_Status0  PAD4_Units0  PAD3_Status0  \
# 0          61         117             1     1.198863           1.0
# 1          88         180             0     0.000000           NaN
# 2          58          99             0     0.000000           NaN
# 3          99         127             1     3.070950           0.0
# 4           3           4             0     0.000000           NaN
#
#    PAD3_Units0
# 0      0.87305
# 1          NaN
# 2          NaN
# 3      0.00000
# 4          NaN

# %%
df1=df1.drop(["pid","PAD4_Status0","PAD3_Status0","PAD3_Units0"], axis = 1)
df1.shape
# Out:
# (89, 9)

# %%
plt.figure(figsize  = (10, 10))

sns.heatmap(df1.corr(), annot = True, cmap = "YlGnBu")

plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-438c486f-3cc7-4623-8859-c496c3095b57" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-438c486f-3cc7-4623-8859-c496c3095b57">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
df2 = pd.read_csv(io.BytesIO(uploaded[ 'cytokine.csv' ]))
df2.head()
# Out:
#      pid  AgeRA  AgeScreen  DisDurMonths    IFNGR1    IFNGR2   IL_1b   IL_2  \
# 0  X1001   54.6       57.0            29  0.042588  0.931017    8.12   3.18
# 1  X1004   49.8       57.1            87  0.034166  0.281233   89.59   5.63
# 2  X1005   18.3       55.6           447  0.070039  0.715094    0.00   0.00
# 3  X1006   45.0       55.3           124  0.023560  0.413735    0.00   0.00
# 4  X1007   28.0       42.3           171  0.025762  0.562074  332.27  16.37
#
#    IL_4  IL_5  ...  IL_10  IL_12  IL_13  IL_17   ACSF  GMCSF  IFN_g    MCP_1  \
# 0  1.20   0.0  ...   0.00   0.00    0.0   7.53   4.02  14.03  30.05  1598.97
# 1  3.98   0.0  ...   2.56  26.59    0.0  73.24  18.13   9.92  59.90   433.25
# 2  0.00   0.0  ...   0.00   0.00    0.0  11.14   0.67   4.95   7.79   168.12
# 3  0.00   0.0  ...   0.00   0.00    0.0   6.79   5.43   4.95   9.06    39.56
# 4  3.83   0.0  ...  24.51  64.25    0.0  66.73  17.08  10.75  51.58   266.99
#
#        MIP  TNF_a
# 0   122.40   0.00
# ...

# %%
df2=df2.drop(["pid"], axis = 1)
df2.shape
# Out:
# (577, 22)

# %%
plt.figure(figsize  = (10, 10))

sns.heatmap(df2.corr(), annot = True, cmap = "YlGnBu")

plt.show()
